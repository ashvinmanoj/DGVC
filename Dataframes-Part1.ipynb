# %% [markdown]
# ### Creating a List
# A list can have an integer, float, character or combination of all

# %%
data_list= [ 1,2,4,5,6]
data_list1= ["name1", "name2", "name3"]
data_list2= [1,"name1",3,"name2","name3",5]
print(data_list)
print(data_list1)
print(data_list2)
# Out:
# [1, 2, 4, 5, 6]
# ['name1', 'name2', 'name3']
# [1, 'name1', 3, 'name2', 'name3', 5]

# %% [markdown]
# ### Creating a Dictionary
# A dictionary can have an integer, float, character or combination of all

# %%
dict_data = {  "calories": 420,   "duration": 50 }
dict_data1 = dict(calories=  420,   duration = 50)
print(dict_data)
print(dict_data1)
# Out:
# {'calories': 420, 'duration': 50}
# {'calories': 420, 'duration': 50}

# %% [markdown]
# #### Dictionary with values as list and set

# %%
dict_data = dict(calories= [420, 380, 390],  duration= [50, 40, 45] )
dict_data1 = dict(calories= (420, 380, 390),  duration= (50, 40, 45) )
print(dict_data)
print(dict_data1)
# Out:
# {'calories': [420, 380, 390], 'duration': [50, 40, 45]}
# {'calories': (420, 380, 390), 'duration': (50, 40, 45)}

# %% [markdown]
# ### Dataframe
#
# **A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.**
#
# #### Features of DataFrame
# * *Potentially columns are of different types*
# * *Size – Mutable*
# * *Labeled axes (rows and columns)*
# * *Can Perform Arithmetic operations on rows and columns*

# %% [markdown]
# ### Structure
#
# **Let us assume that we are creating a data frame with student’s data.**
#
# ![image.png](attachment:5ff7ffb6-6328-40cf-b4cc-30af9050009a.png)

# %% [markdown]
# ### pandas.DataFrame
# **A pandas DataFrame can be created using the following constructor**
#
# *pandas.DataFrame( data, index, columns, dtype, copy)*
#
# **data**
# *data takes various forms like ndarray, series, map, lists, dict, constants and also another DataFrame.*
#
# **index**
# *For the row labels, the Index to be used for the resulting frame is Optional Default np.arange(n) if no index is passed.*
#
#
# **Columns**
# *For column labels, the optional default syntax is - np.arange(n). This is only true if no index is passed.*
#
# **dtype**
# *Data type of each column.*
#
# **copy**
# *This command (or whatever it is) is used for copying of data, if the default is False.*

# %% [markdown]
# ### Create DataFrame
# **A pandas DataFrame can be created using various inputs like −**
#
# * Lists
# * dict
# * Series
# * Numpy ndarrays
# * Another DataFrame

# %% [markdown]
# ### Create an Empty DataFrame

# %%
import pandas as pd
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data = { 'name': ['Xavier', 'Ann', 'Jana', 'Yi', 'Robin', 'Amal', 'Nori'],
         'city': ['Mexico City', 'Toronto', 'Prague', 'Shanghai',
         'Manchester', 'Cairo', 'Osaka'],
         'age': [41, 28, 33, 34, 38, 31, 37],
         'py-score': [88.0, 79.0, 81.0, 80.0, 68.0, 61.0, 84.0] }

row_labels = [101, 102, 103, 104, 105, 106, 107]

# %% [markdown]
# **data** is a Python variable that refers to the dictionary that holds your candidate data. It also contains the labels of the columns:
#
# * 'name'
# * 'city'
# * 'age'
# * 'py-score'
#
# **row_labels** refers to a list that contains the labels of the rows, which are numbers ranging from 101 to 107.

# %%
import pandas as pd
df = pd.DataFrame(data=data, index=row_labels)
print(df)
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 105   Robin   Manchester   38      68.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %% [markdown]
# ![image.png](attachment:74b04485-25dd-41b7-bd5b-d7d6653e7764.png)

# %% [markdown]
# ### Create a DataFrame from Lists
# The DataFrame can be created using a single list or a list of lists.

# %%
import pandas as pd
data = [1,2,3,4,5]
df = pd.DataFrame(data)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
import pandas as pd
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data)
print(df)
# Out:
#         0   1
# 0    Alex  10
# 1     Bob  12
# 2  Clarke  13

# %%
import pandas as pd
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %%
import pandas as pd
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %% [markdown]
# **Get a series from Dataframe**

# %%
df['Name']
# Out:
# 0      Alex
# 1       Bob
# 2    Clarke
# Name: Name, dtype: object

# %%
df['Age']
# Out:
# 0    10
# 1    12
# 2    13
# Name: Age, dtype: int64

# %%
import pandas as pd
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'],dtype=float)
print(df['Age'])
# Out:
# 0    10.0
# 1    12.0
# 2    13.0
# Name: Age, dtype: float64

# %% [markdown]
# **Get a dataframe from a dataframe by selecting a single column or multiple columns**

# %%
df[['Age']]
# Out:
#     Age
# 0  10.0
# 1  12.0
# 2  13.0

# %% [markdown]
# ### Create a DataFrame from Dict of ndarrays / Lists
#
# All the **ndarrays** must be of same length. If **index** is passed, then the length of the index should equal to the length of the arrays.
#
# If no index is passed, then by default, index will be **range(n)**, where n is the array length.

# %%
import pandas as pd
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],
        'Age':[28,34,29,42]}
df = pd.DataFrame(data)
print(df)
# Note − Observe the values 0,1,2,3. They are the default index assigned to each using the function range(n).
# Out:
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42

# %% [markdown]
# ### Exercise
# Create an indexed DataFrame using arrays.

# %%
#SOLUTION

import numpy as np
import pandas as pd
columns = ["A", "B", "C"]
rows = ["D", "E", "F"]
data = np.array([[1, 2, 2], [3, 3, 3],[4, 4, 4]])
df = pd.DataFrame(data=data, index=rows, columns=columns)
df
# Out:
#    A  B  C
# D  1  2  2
# E  3  3  3
# F  4  4  4

# %% [markdown]
# ### Create a DataFrame from List of Dicts
# List of Dictionaries can be passed as input data to create a DataFrame. The dictionary keys are by default taken as column names.

# %%
import pandas as pd
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df = pd.DataFrame(data)
print(df)
# Note − Observe, NaN (Not a Number) is appended in missing areas.
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %% [markdown]
# The following example shows how to create a DataFrame with a list of dictionaries, row indices, and column indices.

# %%
import pandas as pd
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]

#With two column indices, values same as dictionary keys
df1 = pd.DataFrame(data, index=['first', 'second'], 
                   columns=['a', 'b'])

#With two column indices with one index with other name
df2 = pd.DataFrame(data, index=['first', 'second'], 
                   columns=['a', 'b1'])
print(df1)
print(df2)
# Out:
#         a   b
# first   1   2
# second  5  10
#         a  b1
# first   1 NaN
# second  5 NaN

# %% [markdown]
# In above example − Observe, df2 DataFrame is created with a column index other than the dictionary key; thus, appended the NaN’s in place. Whereas, df1 is created with column indices same as dictionary keys, so NaN’s appended.

# %% [markdown]
# ### Convert dataframe columns into List or Series

# %%
import pandas as pd
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}
df = pd.DataFrame(data)

print(type(df['Age']))
print(type(df['Age'].to_list()))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'list'>

# %%
import pandas as pd
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}
df = pd.DataFrame(data)

print(df['Age'])
print(df['Age'].to_list())
# Out:
# 0    28
# 1    34
# 2    29
# 3    42
# Name: Age, dtype: int64
# [28, 34, 29, 42]

# %% [markdown]
# ### Create a DataFrame from Dict of Series
# Dictionary of Series can be passed to form a DataFrame. The resultant index is the union of all the series indexes passed.

# %%
import pandas as pd
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}
df = pd.DataFrame(d)
print(df)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %% [markdown]
# ### Column Selection
# We will understand this by selecting a column from the DataFrame.

# %%
import pandas as pd

d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)
print(df['one'])
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %% [markdown]
# ### Column Addition
# We will understand this by adding a new column to an existing data frame.

# %%
import pandas as pd
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}
df = pd.DataFrame(d)

# Adding a new column to an existing DataFrame object with column label by passing new series

print ("Adding a new column by passing as Series:")
df['three']=pd.Series([10,20,30],index=['a','b','c'])
print(df)
print ("Adding a new column using the existing columns in DataFrame:")
df['four']=df['one']+df['three']
print(df)
# Out:
# Adding a new column by passing as Series:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
# Adding a new column using the existing columns in DataFrame:
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  NaN    4    NaN   NaN

# %% [markdown]
# ### Column Deletion
# Columns can be deleted or popped; let us take an example to understand how.

# %%
# Using the previous DataFrame, we will delete a column
# using del function
import pandas as pd

d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']), 
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd']), 
   'three' : pd.Series([10,20,30], index=['a','b','c'])}

df = pd.DataFrame(d)
print ("Our dataframe is:")
print(df)

# using del function
print ("Deleting the first column using DEL function:")
del df['one']
print(df)

# using pop function
print ("Deleting another column using POP function:")
df.pop('two')
print(df)
# Out:
# Our dataframe is:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
# Deleting the first column using DEL function:
#    two  three
# a    1   10.0
# b    2   20.0
# c    3   30.0
# d    4    NaN
# Deleting another column using POP function:
#    three
# a   10.0
# b   20.0
# c   30.0
# d    NaN

# %% [markdown]
# ### Exercise

# %%
# Create a dataframe with 5 columns 
# Name the columns with Weekdays
# Add 4 sessions i.e. Morning, Afternoon Evening and Night as index
# Add random temperatures for each day in the 4 sessions of the day
# Display the 3rd Weekday column alone

# %%
# SOLUTION

dict_ = {
    "Monday": [10,12,13,14],
    "Tuesday": [22,24,23,24],
    "Wednesday": [10,15,29,29],
    "Thursday": [21.5,23,23.7,19],
    "Friday": [12,18,24,8]
}
index = ["Morning", "Afternoon", "Evening", "Night"]
df = pd.DataFrame(data=dict_, index=index)
df
# Out:
#            Monday  Tuesday  Wednesday  Thursday  Friday
# Morning        10       22         10      21.5      12
# Afternoon      12       24         15      23.0      18
# Evening        13       23         29      23.7      24
# Night          14       24         29      19.0       8

# %% [markdown]
# ### Exercise
# * What is the datatype of df.columns and df.index
# * Convert the above to List,or set

# %% [markdown]
# **Get all index values**

# %%
df.index
# Out:
# Index(['Morning', 'Afternoon', 'Evening', 'Night'], dtype='object')

# %% [markdown]
# **Get all column names**

# %%
df.columns
# Out:
# Index(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'], dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.columns.to_list()
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame([('falcon', 'bird', 389.0),
                   ('parrot', 'bird', 24.0),
                   ('lion', 'mammal', 80.5),
                   ('monkey', 'mammal', np.nan)],
                  columns=('name', 'class', 'max_speed'))
df
# Out:
#      name   class  max_speed
# 0  falcon    bird      389.0
# 1  parrot    bird       24.0
# 2    lion  mammal       80.5
# 3  monkey  mammal        NaN

# %% [markdown]
# ### Selecting data from dataframe
# When it comes to select data on a DataFrame, Pandas loc and iloc are two top favorites. They are quick, fast, easy to read, and sometimes interchangeable.
#
# We will go over the following topics:
#
# 1. Differences between loc and iloc
# 2. Selecting via a single value
# 3. Selecting via a list of values
# 4. Selecting a range of data via slice
# 5. Selecting via conditions and callable
# 6. loc and iloc are interchangeable when labels are 0-based integers

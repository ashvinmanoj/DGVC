# %% [markdown]
# # Merge, Join, Concat in python

# %%
import pandas as pd
climate_temp = pd.read_csv("https://raw.githubusercontent.com/realpython/materials/master/introduction-combining-data-pandas-merge-join-and-concat/climate_temp.csv")
climate_temp
# Out:
#                   STATION            STATION_NAME ELEVATION  LATITUDE  \
# 0       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 1       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 2       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 3       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 4       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# ...                   ...                     ...       ...       ...
# 127015  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 127016  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 127017  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 127018  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 127019  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
#
#          LONGITUDE      DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# ...

# %%
import pandas as pd
climate_precip = pd.read_csv("https://raw.githubusercontent.com/realpython/materials/master/introduction-combining-data-pandas-merge-join-and-concat/climate_precip.csv")
climate_precip
# Out:
#                   STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4       GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
# ...                   ...                     ...       ...              ...
# 151105  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101227             0.12
# 151106  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101228             0.12
# 151107  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101229             0.12
# 151108  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101230             0.12
# 151109  GHCND:USC00046006  MOUNT WILSON CBS CA US  20101231             0.12
#
# ...

# %% [markdown]
# ### Datafarme dimensions

# %%
climate_temp.shape
# Out:
# (127020, 21)

# %%
climate_precip.shape
# Out:
# (151110, 29)

# %% [markdown]
# ## How to Use merge()
# #### Before getting into the details of how to use merge(), you should first understand the various forms of joins:
#
# 1.inner
#
# 2.outer
#
# 3.left
#
# 4.right

# %% [markdown]
# ## Note:
#
# Even though you’re learning about merging, you’ll see inner, outer, left, and right also referred to as join operations. For this tutorial, you can consider the terms merge and join equivalent.

# %% [markdown]
# ![image info](https://files.realpython.com/media/join_diagram.93e6ef63afbe.png)

# %% [markdown]
# **1. Inner Join**

# %%
inner_merged = pd.merge(climate_precip, climate_temp)
inner_merged.shape
# Out:
# (123005, 47)

# %%
pd.set_option('display.max_columns', None)
inner_merged.head(5)
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6            -6.66             -666
# 1             -666            -66.6            -6.66             -666
# 2             -666            -66.6            -6.66             -666
# 3            -9999          -9999.0            -6.66            -9999
# 4            -9999          -9999.0            -6.66            -9999
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  DLY-SNWD-75PCTL  DLY-SNOW-75PCTL  \
# ...

# %%
climate_precip.STATION.value_counts()
# Out:
# GHCND:USC00048713    365
# GHCND:USC00049785    365
# GHCND:USC00040232    365
# GHCND:USC00040029    365
# GHCND:USW00003166    365
#                     ...
# GHCND:USC00042410    365
# GHCND:USC00046508    365
# GHCND:USC00042327    365
# GHCND:USW00023232    365
# GHCND:USC00049073    365
# Name: STATION, Length: 414, dtype: int64

# %% [markdown]
# **What if you want to merge both full datasets, but specify which columns to join on? In this case, you will use the on parameter:**

# %%
inner_merged_total = pd.merge(climate_temp, climate_precip, on=["STATION", "DATE"])
inner_merged_total.shape
# Out:
# (123005, 48)

# %% [markdown]
# *Why 48 columns instead of 47? Because you specified the keys columns to join on, Pandas doesn't try to merge all mergeable columns. This can result in "duplicate" column names, which may or may not have different values. "Duplicate" is in quotes because the columns will actually have new names, by default they are appended with _x and _y. You can also use the suffixes parameter to control what is appended to the column names.*

# %% [markdown]
# **2. Outer Join**

# %%
outer_merged = pd.merge(climate_precip, climate_temp, how="outer", on=["STATION", "DATE"])
print(outer_merged.shape)
# Out:
# (155125, 48)

# %% [markdown]
# **3. Left Join**

# %%
left_merged = pd.merge(climate_temp, climate_precip, how="left", on=["STATION", "DATE"])
left_merged.shape
# Out:
# (127020, 48)

# %%
left_merged = pd.merge(climate_precip,climate_temp, how="left", on=["STATION", "DATE"])
left_merged.shape
# Out:
# (151110, 48)

# %% [markdown]
# **4. Right join**

# %%
right_merged = pd.merge(climate_precip, climate_temp, how="right", on=["STATION", "DATE"])
right_merged.shape
# Out:
# (127020, 48)

# %%
right_merged = pd.merge(climate_temp,climate_precip, how="right", on=["STATION", "DATE"])
right_merged.shape
# Out:
# (151110, 48)

# %% [markdown]
# **Concat()**

# %%
double_precip = pd.concat([climate_precip, climate_temp])
double_precip.shape
# Out:
# (278130, 47)

# %%
data_sample1= climate_precip[climate_precip.STATION == 'GHCND:USC00044863']
data_sample2= climate_precip[climate_precip.STATION == 'GHCND:USC00046719']

# %%
data_concat = pd.concat([data_sample1,data_sample2])
data_concat.shape
# Out:
# (730, 29)

# %%
data_concat = pd.concat([data_sample1,climate_temp])
data_concat.shape
# Out:
# (127385, 47)

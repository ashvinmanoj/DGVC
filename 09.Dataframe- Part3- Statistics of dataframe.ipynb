# %%
import pandas as pd

 
url= "https://raw.githubusercontent.com/RandomFractals/chicago-crimes/main/data/crimes-2022.csv"
data=pd.read_csv(url)
data['Row Number']= data.index
data=data.set_index('Case Number')
data
# Out:
#                    ID                    Date                   Block  IUCR  \
# Case Number
# JF313117     12757446  07/08/2022 10:38:00 AM  087XX S WINCHESTER AVE  0820
# JF310109     12755229  07/08/2022 03:21:00 AM   056XX N SPAULDING AVE  1154
# JF320208     12763369  07/16/2022 10:55:00 PM   038XX N SHEFFIELD AVE  0330
# JF323691     12766036  07/19/2022 04:00:00 PM     113XX S PARNELL AVE  1792
# JF314314     12758668  07/12/2022 06:30:00 AM       044XX W WALTON ST  0610
# ...               ...                     ...                     ...   ...
# JF315350     12759190  07/09/2022 07:00:00 AM     098XX S CALHOUN AVE  0820
# JF321506     12765045  07/08/2022 02:00:00 PM    006XX S MICHIGAN AVE  0810
# JF294494     12742026  06/24/2022 03:43:00 PM        075XX N CLARK ST  0860
# JF313061     12757420  07/01/2022 12:00:00 AM          001XX N MAY ST  0281
# JF317539     12760994  07/14/2022 02:45:00 PM     063XX S WESTERN AVE  0460
#
# ...

# %% [markdown]
# ### Statistic of the dataset
# #### The number of rows and columns in the dataset; returns a tuple

# %%
data.shape
# Out:
# (215551, 22)

# %% [markdown]
# #### Summary Statistics of the data- only returns result for numeric columns and string (Object) columns are ignored

# %%
data.describe()
# Out:
#                  ID           Beat       District           Ward  \
# count  2.155510e+05  215551.000000  215551.000000  215541.000000
# mean   1.271186e+07    1151.768087      11.287616      23.345619
# std    7.033576e+05     708.244930       7.078264      14.219561
# min    2.654300e+04     111.000000       1.000000       1.000000
# 25%    1.266904e+07     533.000000       5.000000       9.000000
# 50%    1.275145e+07    1032.000000      10.000000      24.000000
# 75%    1.283126e+07    1731.000000      17.000000      35.000000
# max    1.291490e+07    2535.000000      31.000000      50.000000
#
#        Community Area  X Coordinate  Y Coordinate      Year       Latitude  \
# count   215551.000000  2.140770e+05  2.140770e+05  215551.0  214077.000000
# mean        36.293128  1.165422e+06  1.886940e+06    2022.0      41.845342
# std         21.536399  1.679156e+04  3.230926e+04       0.0       0.088871
# min          1.000000  0.000000e+00  0.000000e+00    2022.0      36.619446
# ...

# %% [markdown]
# #### Dataset information
#
# **Note:**
#
# Some of the columns have null values and those column count will not match the index count. for example column Latitude has 1474 null values in it.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215551 entries, JF313117 to JF317539
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    215551 non-null  int64
#  1   Date                  215551 non-null  object
#  2   Block                 215551 non-null  object
#  3   IUCR                  215551 non-null  object
#  4   Primary Type          215551 non-null  object
#  5   Description           215551 non-null  object
#  6   Location Description  214940 non-null  object
#  7   Arrest                215551 non-null  bool
#  8   Domestic              215551 non-null  bool
#  9   Beat                  215551 non-null  int64
#  10  District              215551 non-null  int64
#  11  Ward                  215541 non-null  float64
#  12  Community Area        215551 non-null  int64
#  13  FBI Code              215551 non-null  object
# ...

# %% [markdown]
# #### What are Features in a dataset?

# %%
list(data.columns)
# Out:
# ['ID',
#  'Date',
#  'Block',
#  'IUCR',
#  'Primary Type',
#  'Description',
#  'Location Description',
#  'Arrest',
#  'Domestic',
#  'Beat',
#  'District',
#  'Ward',
#  'Community Area',
#  'FBI Code',
#  'X Coordinate',
#  'Y Coordinate',
#  'Year',
#  'Updated On',
#  'Latitude',
#  'Longitude',
#  'Location',
#  'Row Number']

# %% [markdown]
# #### Number of Distinct Crimes in the city of Chicago

# %%
crimes = data['Date'].unique()
print("The Number of distinct crimes in Chicago in the year 2018:", len(crimes))
print()
print("The Distinct Crimes are :\n", crimes)
# Out:
# The Number of distinct crimes in Chicago in the year 2018: 102268
#
# The Distinct Crimes are :
#  ['07/08/2022 10:38:00 AM' '07/08/2022 03:21:00 AM'
#  '07/16/2022 10:55:00 PM' ... '07/09/2022 02:25:00 AM'
#  '06/02/2022 09:35:00 AM' '06/24/2022 03:43:00 PM']

# %%
data.Date
# Out:
# Case Number
# JF313117    07/08/2022 10:38:00 AM
# JF310109    07/08/2022 03:21:00 AM
# JF320208    07/16/2022 10:55:00 PM
# JF323691    07/19/2022 04:00:00 PM
# JF314314    07/12/2022 06:30:00 AM
#                      ...
# JF315350    07/09/2022 07:00:00 AM
# JF321506    07/08/2022 02:00:00 PM
# JF294494    06/24/2022 03:43:00 PM
# JF313061    07/01/2022 12:00:00 AM
# JF317539    07/14/2022 02:45:00 PM
# Name: Date, Length: 215551, dtype: object

# %%
data1=data
data1['Date'] = pd.to_datetime(data1['Date'])
data1.Date
# Out:
# Case Number
# JF313117   2022-07-08 10:38:00
# JF310109   2022-07-08 03:21:00
# JF320208   2022-07-16 22:55:00
# JF323691   2022-07-19 16:00:00
# JF314314   2022-07-12 06:30:00
#                    ...
# JF315350   2022-07-09 07:00:00
# JF321506   2022-07-08 14:00:00
# JF294494   2022-06-24 15:43:00
# JF313061   2022-07-01 00:00:00
# JF317539   2022-07-14 14:45:00
# Name: Date, Length: 215551, dtype: datetime64[ns]

# %% [markdown]
# #### Convert a object datatype into a Datetime datatype

# %%
data.Date
# Out:
# Case Number
# JF313117   2022-07-08 10:38:00
# JF310109   2022-07-08 03:21:00
# JF320208   2022-07-16 22:55:00
# JF323691   2022-07-19 16:00:00
# JF314314   2022-07-12 06:30:00
#                    ...
# JF315350   2022-07-09 07:00:00
# JF321506   2022-07-08 14:00:00
# JF294494   2022-06-24 15:43:00
# JF313061   2022-07-01 00:00:00
# JF317539   2022-07-14 14:45:00
# Name: Date, Length: 215551, dtype: datetime64[ns]

# %% [markdown]
# ### Pandas Extract Month and Year from Datetime
# #### What is a panda series?

# %% [markdown]
# #### Exercise: Give an example of Panda series

# %%
data.Block
# Out:
# Case Number
# JF313117    087XX S WINCHESTER AVE
# JF310109     056XX N SPAULDING AVE
# JF320208     038XX N SHEFFIELD AVE
# JF323691       113XX S PARNELL AVE
# JF314314         044XX W WALTON ST
#                      ...
# JF315350       098XX S CALHOUN AVE
# JF321506      006XX S MICHIGAN AVE
# JF294494          075XX N CLARK ST
# JF313061            001XX N MAY ST
# JF317539       063XX S WESTERN AVE
# Name: Block, Length: 215551, dtype: object

# %% [markdown]
# #### Extract Year, Month and Day from datetime datatype

# %%
data1['Date'].dt.year
# Out:
# Case Number
# JF313117    2022
# JF310109    2022
# JF320208    2022
# JF323691    2022
# JF314314    2022
#             ...
# JF315350    2022
# JF321506    2022
# JF294494    2022
# JF313061    2022
# JF317539    2022
# Name: Date, Length: 215551, dtype: int64

# %%
data1['Date'].dt.month
# Out:
# Case Number
# JF313117    7
# JF310109    7
# JF320208    7
# JF323691    7
# JF314314    7
#            ..
# JF315350    7
# JF321506    7
# JF294494    6
# JF313061    7
# JF317539    7
# Name: Date, Length: 215551, dtype: int64

# %%
data1['Date'].dt.day
# Out:
# Case Number
# JF313117     8
# JF310109     8
# JF320208    16
# JF323691    19
# JF314314    12
#             ..
# JF315350     9
# JF321506     8
# JF294494    24
# JF313061     1
# JF317539    14
# Name: Date, Length: 215551, dtype: int64

# %% [markdown]
# ### Python Strftime Format
# #### The strftime converts date object to a string date.
#
# #### The syntax of strftime() method is -> strftime(dateType, format)

# %%
import datetime 
# from datetime import datetime
now = datetime.datetime.now()
print(now)
print(type(now))
print(now.strftime("%Y-%m-%d %H:%m:%S"))
print(type(now.strftime("%Y-%m-%d %H:%M:%S")))
# Out:
# 2023-03-20 16:39:28.870357
# <class 'datetime.datetime'>
# 2023-03-20 16:03:28
# <class 'str'>

# %% [markdown]
# ![image.png](attachment:3d3cfaa8-be63-4887-9e20-302ac45ee6c9.png)

# %% [markdown]
# #### Datetime To String Python using strftime()

# %%
now.strftime("%Y-%b-%d %H:%M:%S")
# Out:
# '2023-Mar-20 16:39:28'

# %%
now.strftime("%Y/%b/%A %H:%M:%S")
# Out:
# '2023/Mar/Monday 16:39:28'

# %% [markdown]
# #### Date To String Python using strftime()

# %%
import datetime 
today = datetime.datetime.today()
print(today)
# Out:
# 2023-03-20 16:39:48.450572

# %%
today.strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2023-03-20 16:39:48'

# %% [markdown]
# #### Exercise: Get Python date as string using Strftime with no time component

# %%
#Solution

today.strftime("%Y-%m-%d")
# Out:
# '2023-03-20'

# %% [markdown]
# ### Python Strptime Format
# #### Strptime python is used to convert string to datetime object.
#
# *strptime(date_string, format)*

# %%
import datetime
datetime.datetime.strptime("09/23/2030 8:28","%m/%d/%Y %H:%M")
# Out:
# datetime.datetime(2030, 9, 23, 8, 28)

# %%
data1['Date']
# Out:
# Case Number
# JF313117   2022-07-08 10:38:00
# JF310109   2022-07-08 03:21:00
# JF320208   2022-07-16 22:55:00
# JF323691   2022-07-19 16:00:00
# JF314314   2022-07-12 06:30:00
#                    ...
# JF315350   2022-07-09 07:00:00
# JF321506   2022-07-08 14:00:00
# JF294494   2022-06-24 15:43:00
# JF313061   2022-07-01 00:00:00
# JF317539   2022-07-14 14:45:00
# Name: Date, Length: 215551, dtype: datetime64[ns]

# %%
data1['Date'].dt.strftime('%m-%Y-%d')
# Out:
# Case Number
# JF313117    07-2022-08
# JF310109    07-2022-08
# JF320208    07-2022-16
# JF323691    07-2022-19
# JF314314    07-2022-12
#                ...
# JF315350    07-2022-09
# JF321506    07-2022-08
# JF294494    06-2022-24
# JF313061    07-2022-01
# JF317539    07-2022-14
# Name: Date, Length: 215551, dtype: object

# %%
data1['Date'].dt.strftime('%b-%Y-%d')
# Out:
# Case Number
# JF313117    Jul-2022-08
# JF310109    Jul-2022-08
# JF320208    Jul-2022-16
# JF323691    Jul-2022-19
# JF314314    Jul-2022-12
#                ...
# JF315350    Jul-2022-09
# JF321506    Jul-2022-08
# JF294494    Jun-2022-24
# JF313061    Jul-2022-01
# JF317539    Jul-2022-14
# Name: Date, Length: 215551, dtype: object

# %% [markdown]
# ### Import flight data frim the internet

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/JackyP/testing/master/datasets/nycflights.csv", usecols=range(1,17))
df
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     544.0       -1.0    1004.0      -18.0      B6
# 4       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 336771  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336772  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336773  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336774  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336775  2013      9   30       NaN        NaN       NaN        NaN      MQ
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %% [markdown]
# #### Get information about the flight information dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 16 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   year       336776 non-null  int64
#  1   month      336776 non-null  int64
#  2   day        336776 non-null  int64
#  3   dep_time   328521 non-null  float64
#  4   dep_delay  328521 non-null  float64
#  5   arr_time   328063 non-null  float64
#  6   arr_delay  327346 non-null  float64
#  7   carrier    336776 non-null  object
#  8   tailnum    334264 non-null  object
#  9   flight     336776 non-null  int64
#  10  origin     336776 non-null  object
#  11  dest       336776 non-null  object
#  12  air_time   327346 non-null  float64
#  13  distance   336776 non-null  int64
#  14  hour       328521 non-null  float64
#  15  minute     328521 non-null  float64
# dtypes: float64(7), int64(5), object(4)
# memory usage: 41.1+ MB

# %% [markdown]
# #### Select flights details of JetBlue Airways that has 2 letters carrier code B6 with origin from JFK airport

# %%
df[(df.origin == "JFK") & (df.carrier == "B6")]
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 3       2013      1    1     544.0       -1.0    1004.0      -18.0      B6
# 8       2013      1    1     557.0       -3.0     838.0       -8.0      B6
# 10      2013      1    1     558.0       -2.0     849.0       -2.0      B6
# 11      2013      1    1     558.0       -2.0     853.0       -3.0      B6
# 15      2013      1    1     559.0        0.0     702.0       -4.0      B6
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 336765  2013      9   30    2240.0       -5.0    2334.0      -17.0      B6
# 336766  2013      9   30    2240.0      -10.0    2347.0      -20.0      B6
# 336767  2013      9   30    2241.0       -5.0    2345.0      -16.0      B6
# 336768  2013      9   30    2307.0       12.0    2359.0        1.0      B6
# 336769  2013      9   30    2349.0      -10.0     325.0      -25.0      B6
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %% [markdown]
# #### Get total count of unique values under a column

# %%
df.origin.value_counts()
# Out:
# EWR    120835
# JFK    111279
# LGA    104662
# Name: origin, dtype: int64

# %%
df.origin.unique()
# Out:
# array(['EWR', 'LGA', 'JFK'], dtype=object)

# %% [markdown]
# #### Sort the total count in ascending order

# %%
df.origin.value_counts(ascending=True)
# Out:
# LGA    104662
# JFK    111279
# EWR    120835
# Name: origin, dtype: int64

# %% [markdown]
# #### Get the total count percent for each value in the column

# %%
df.origin.value_counts(normalize=True)
# Out:
# EWR    0.358799
# JFK    0.330424
# LGA    0.310776
# Name: origin, dtype: float64

# %% [markdown]
# #### Get the total count including NaN values

# %%
df.hour.value_counts(dropna=False, ascending=True)
# Out:
# 3.0        11
# 24.0       29
# 2.0        64
# 1.0       223
# 4.0       305
# 0.0       881
# 23.0     2616
# 22.0     5483
# 5.0      7246
# NaN      8255
# 21.0    10960
# 12.0    16071
# 10.0    16076
# 20.0    16160
# 11.0    16762
# 13.0    16890
# 9.0     18871
# 19.0    19940
# 14.0    20480
# 7.0     21461
# 18.0    21549
# 17.0    22144
# 16.0    22336
# 6.0     22699
# 15.0    22840
# 8.0     26424
# Name: hour, dtype: int64

# %% [markdown]
# #### Get the list of values to be filtered

# %%
df.dest.value_counts()
# Out:
# ORD    17283
# ATL    17215
# LAX    16174
# BOS    15508
# MCO    14082
#        ...
# MTJ       15
# SBN       10
# ANC        8
# LEX        1
# LGA        1
# Name: dest, Length: 105, dtype: int64

# %% [markdown]
# ### Subset dataframe from range of values.

# %%
df[df['dest'].isin(['ORD', 'ATL','LAX','BOS', 'MCO'])]
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 4       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# 5       2013      1    1     554.0       -4.0     740.0       12.0      UA
# 8       2013      1    1     557.0       -3.0     838.0       -8.0      B6
# 9       2013      1    1     558.0       -2.0     753.0        8.0      AA
# 12      2013      1    1     558.0       -2.0     924.0        7.0      UA
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 336744  2013      9   30    2121.0       21.0    2349.0      -25.0      DL
# 336751  2013      9   30    2140.0        0.0      10.0      -30.0      AA
# 336755  2013      9   30    2149.0       -7.0    2245.0      -23.0      UA
# 336763  2013      9   30    2235.0      154.0      59.0      130.0      B6
# 336768  2013      9   30    2307.0       12.0    2359.0        1.0      B6
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %% [markdown]
# #### Its possible to have values in a row as '...' which looks similar to displaying a dataframe where only top 5 and bottom 5 rows were displayed and values between those rows are with '...'.
#
# #### Check this example below

# %%
df1= df[df['dest'].isin(['ORD', 'ATL','LAX','BOS', 'MCO'])]
df1.loc[5,:] = ['...','...','...','...','...','...','...','...','...','...','...','...','...','...','...','...',]
df1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1700: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, v, pi)
#         year month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 4       2013     1    1    554.0      -6.0    812.0     -25.0      DL  N668DN
# 5        ...   ...  ...      ...       ...      ...       ...     ...     ...
# 8       2013     1    1    557.0      -3.0    838.0      -8.0      B6  N593JB
# 9       2013     1    1    558.0      -2.0    753.0       8.0      AA  N3ALAA
# 12      2013     1    1    558.0      -2.0    924.0       7.0      UA  N29129
# ...      ...   ...  ...      ...       ...      ...       ...     ...     ...
# ...

# %% [markdown]
# ### Rename a dataframe column

# %%
df.rename(columns={"dest": "destination", "tailnum": "tail_num"}, inplace=True)

# %%
df.rename({"destination": "dest", "tail_num": "tailnum"}, axis=1,inplace=True)

# %%
df.rename(columns=dict(dest='destination', tailnum="tail_num"), inplace=True)
df
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     544.0       -1.0    1004.0      -18.0      B6
# 4       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 336771  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336772  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336773  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336774  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336775  2013      9   30       NaN        NaN       NaN        NaN      MQ
#
# ...

# %%
df.rename(str.upper, axis='columns')
# Out:
#         YEAR  MONTH  DAY  DEP_TIME  DEP_DELAY  ARR_TIME  ARR_DELAY CARRIER  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     544.0       -1.0    1004.0      -18.0      B6
# 4       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 336771  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336772  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336773  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336774  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336775  2013      9   30       NaN        NaN       NaN        NaN      MQ
#
# ...

# %%
df.rename({"destination": "dest", "tail_num": "tailnum"}, axis=1,inplace=True)
df
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     544.0       -1.0    1004.0      -18.0      B6
# 4       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 336771  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336772  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336773  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336774  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336775  2013      9   30       NaN        NaN       NaN        NaN      MQ
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# ...
